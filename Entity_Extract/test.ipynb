# %%
from EntityExtractorv2 import medical_term
# Out:
# /home/gholipos-admin/anaconda3/envs/MCSE_2/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_sci_md' (0.5.3) was trained with spaCy v3.6.1 and may not be 100% compatible with the current version (3.7.6). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /home/gholipos-admin/anaconda3/envs/MCSE_2/lib/python3.9/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
caption = "Allowing for the portable technique, the cardiac silhouette may be mildly enlarged. Obliquity of the patient is probably responsible for the apparent displacement of the heart into the left hemithorax."
medical_term(caption)
# Out:
# ['portable technique',
#  'cardiac silhouette',
#  'mildly enlarged',
#  'obliquity',
#  'the the patient',
#  'displacement',
#  'the the heart',
#  'the the left hemithorax']
