# %%
import os

def print_tree(start_path='.', prefix=''):
    files = os.listdir(start_path)
    files.sort()
    for index, name in enumerate(files):
        path = os.path.join(start_path, name)
        is_last = index == len(files) - 1
        connector = '└── ' if is_last else '├── '
        print(prefix + connector + name)
        if os.path.isdir(path):
            extension = '    ' if is_last else '│   '
            print_tree(path, prefix + extension)

# Example usage:
print_tree('./')
# Out:
# ├── CXR-Gen
# │   ├── LICENSE
# │   ├── LungDetection
# │   │   ├── __init__.py
# │   │   ├── __pycache__
# │   │   │   ├── __init__.cpython-38.pyc
# │   │   │   └── main.cpython-38.pyc
# │   │   ├── main.py
# │   │   ├── models
# │   │   │   ├── unet-2v.pt
# │   │   │   └── unet-6v.pt
# │   │   └── src
# │   │       ├── __pycache__
# │   │       │   ├── data.cpython-39.pyc
# │   │       │   ├── metrics.cpython-39.pyc
# │   │       │   ├── models.cpython-37.pyc
# │   │       │   ├── models.cpython-38.pyc
# │   │       │   └── models.cpython-39.pyc
# │   │       ├── data.py
# │   │       ├── metrics.py
# │   │       └── models.py
# │   ├── README.md
# │   ├── Untitled.ipynb
# │   ├── __init__.py
# │   ├── __pycache__
# │   │   ├── config.cpython-310.pyc
# │   │   ├── config.cpython-38.pyc
# │   │   └── config.graalpy223-38.pyc
# │   ├── annotator
# │   │   ├── .ipynb_checkpoints
# │   │   │   └── util-checkpoint.py
# │   │   ├── __pycache__
# │   │   │   └── util.cpython-38.pyc
# ...

# %%
import os
import re

def fix_annotator_imports(root_dir):
    # Match 'from annotator.xxx import ...'
    from_pattern = re.compile(r'^(\s*from\s+)annotator(\.[\w\.]*\s+import\s+.+)')
    # Match 'import annotator.xxx'
    import_pattern = re.compile(r'^(\s*import\s+)annotator(\.[\w\.]*)')

    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.py'):
                filepath = os.path.join(dirpath, filename)
                with open(filepath, 'r', encoding='utf-8') as f:
                    lines = f.readlines()

                new_lines = []
                changed = False

                for line in lines:
                    from_match = from_pattern.match(line)
                    import_match = import_pattern.match(line)

                    if from_match:
                        new_line = f"{from_match.group(1)}CXRGen.annotator{from_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    elif import_match:
                        new_line = f"{import_match.group(1)}CXRGen.annotator{import_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    else:
                        new_lines.append(line)

                if changed:
                    with open(filepath, 'w', encoding='utf-8') as f:
                        f.writelines(new_lines)
                    print(f"Fixed imports in: {filepath}")


# Example usage:
fix_annotator_imports('./CXRGen/annotator/')  # <-- Replace with your actual project root
# Out:
# Fixed imports in: ./CXRGen/annotator/hed/__init__.py
# Fixed imports in: ./CXRGen/annotator/mlsd/__init__.py
# Fixed imports in: ./CXRGen/annotator/openpose/__init__.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/engine/test.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/utils/env.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/utils/config.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/cnn/utils/weight_init.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/cnn/bricks/transformer.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/ops/points_sampler.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/ops/point_sample.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/ops/saconv.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/ops/modulated_deform_conv.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/ops/multi_scale_deform_attn.py
# Fixed imports in: ./CXRGen/annotator/uniformer/mmcv/ops/cc_attention.py
# ...

# %%
import os
import re

def fix_annotator_imports(root_dir):
    # Match 'from annotator.xxx import ...'
    from_pattern = re.compile(r'^(\s*from\s+)groundingdino(\.[\w\.]*\s+import\s+.+)')
    # Match 'import annotator.xxx'
    import_pattern = re.compile(r'^(\s*import\s+)groundingdino(\.[\w\.]*)')

    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.py'):
                filepath = os.path.join(dirpath, filename)
                with open(filepath, 'r', encoding='utf-8') as f:
                    lines = f.readlines()

                new_lines = []
                changed = False

                for line in lines:
                    from_match = from_pattern.match(line)
                    import_match = import_pattern.match(line)

                    if from_match:
                        new_line = f"{from_match.group(1)}CXRGen.groundingdino{from_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    elif import_match:
                        new_line = f"{import_match.group(1)}CXRGen.groundingdino{import_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    else:
                        new_lines.append(line)

                if changed:
                    with open(filepath, 'w', encoding='utf-8') as f:
                        f.writelines(new_lines)
                    print(f"Fixed imports in: {filepath}")


# Example usage:
fix_annotator_imports('./CXRGen/groundingdino/')  # <-- Replace with your actual project root
# Out:
# Fixed imports in: ./CXRGen/groundingdino/util/utils.py
# Fixed imports in: ./CXRGen/groundingdino/util/inference.py
# Fixed imports in: ./CXRGen/groundingdino/util/.ipynb_checkpoints/inference-checkpoint.py
# Fixed imports in: ./CXRGen/groundingdino/models/GroundingDINO/groundingdino.py
# Fixed imports in: ./CXRGen/groundingdino/models/GroundingDINO/transformer.py
# Fixed imports in: ./CXRGen/groundingdino/models/GroundingDINO/backbone/backbone.py
# Fixed imports in: ./CXRGen/groundingdino/models/GroundingDINO/backbone/position_encoding.py
# Fixed imports in: ./CXRGen/groundingdino/models/GroundingDINO/backbone/swin_transformer.py
# Fixed imports in: ./CXRGen/groundingdino/datasets/cocogrounding_eval.py
# Fixed imports in: ./CXRGen/groundingdino/datasets/transforms.py

# %%
import os
import re

def fix_annotator_imports(root_dir):
    # Match 'from annotator.xxx import ...'
    from_pattern = re.compile(r'^(\s*from\s+)ldm(\.[\w\.]*\s+import\s+.+)')
    # Match 'import annotator.xxx'
    import_pattern = re.compile(r'^(\s*import\s+)ldm(\.[\w\.]*)')

    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.py'):
                filepath = os.path.join(dirpath, filename)
                with open(filepath, 'r', encoding='utf-8') as f:
                    lines = f.readlines()

                new_lines = []
                changed = False

                for line in lines:
                    from_match = from_pattern.match(line)
                    import_match = import_pattern.match(line)

                    if from_match:
                        new_line = f"{from_match.group(1)}CXRGen.ldm{from_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    elif import_match:
                        new_line = f"{import_match.group(1)}CXRGen.ldm{import_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    else:
                        new_lines.append(line)

                if changed:
                    with open(filepath, 'w', encoding='utf-8') as f:
                        f.writelines(new_lines)
                    print(f"Fixed imports in: {filepath}")


# Example usage:
fix_annotator_imports('./CXRGen/cldm/')  # <-- Replace with your actual project root
# Out:
# Fixed imports in: ./CXRGen/cldm/cldm.py
# Fixed imports in: ./CXRGen/cldm/hack.py
# Fixed imports in: ./CXRGen/cldm/.ipynb_checkpoints/model-checkpoint.py
# Fixed imports in: ./CXRGen/cldm/.ipynb_checkpoints/cldm-checkpoint.py
# Fixed imports in: ./CXRGen/cldm/.ipynb_checkpoints/hack-checkpoint.py

# %%
import os
import re

def fix_annotator_imports(root_dir):
    # Match 'from annotator.xxx import ...'
    from_pattern = re.compile(r'^(\s*from\s+)ldm(\.[\w\.]*\s+import\s+.+)')
    # Match 'import annotator.xxx'
    import_pattern = re.compile(r'^(\s*import\s+)ldm(\.[\w\.]*)')

    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.py'):
                filepath = os.path.join(dirpath, filename)
                with open(filepath, 'r', encoding='utf-8') as f:
                    lines = f.readlines()

                new_lines = []
                changed = False

                for line in lines:
                    from_match = from_pattern.match(line)
                    import_match = import_pattern.match(line)

                    if from_match:
                        new_line = f"{from_match.group(1)}CXRGen.ldm{from_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    elif import_match:
                        new_line = f"{import_match.group(1)}CXRGen.ldm{import_match.group(2)}\n"
                        new_lines.append(new_line)
                        changed = True
                    else:
                        new_lines.append(line)

                if changed:
                    with open(filepath, 'w', encoding='utf-8') as f:
                        f.writelines(new_lines)
                    print(f"Fixed imports in: {filepath}")


# Example usage:
fix_annotator_imports('./CXRGen/ldm/')  # <-- Replace with your actual project root
# Out:
# Fixed imports in: ./CXRGen/ldm/modules/attention.py
# Fixed imports in: ./CXRGen/ldm/modules/image_degradation/bsrgan.py
# Fixed imports in: ./CXRGen/ldm/modules/image_degradation/bsrgan_light.py
# Fixed imports in: ./CXRGen/ldm/modules/image_degradation/__init__.py
# Fixed imports in: ./CXRGen/ldm/modules/encoders/modules_org.py
# Fixed imports in: ./CXRGen/ldm/modules/encoders/modules.py
# Fixed imports in: ./CXRGen/ldm/modules/encoders/.ipynb_checkpoints/modules_org-checkpoint.py
# Fixed imports in: ./CXRGen/ldm/modules/encoders/.ipynb_checkpoints/modules-checkpoint.py
# Fixed imports in: ./CXRGen/ldm/modules/midas/api.py
# Fixed imports in: ./CXRGen/ldm/modules/midas/.ipynb_checkpoints/api-checkpoint.py
# Fixed imports in: ./CXRGen/ldm/modules/diffusionmodules/openaimodel.py
# Fixed imports in: ./CXRGen/ldm/modules/diffusionmodules/model.py
# Fixed imports in: ./CXRGen/ldm/modules/diffusionmodules/upscaling.py
# ...
